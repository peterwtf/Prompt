# %%
# !pip install transformers==4.25.1
# !pip install pytorch-lightning==1.6.4
# !pip install timm==0.5.4
# !pip install gradio
# !pip install donut-python
# Out:
# Collecting transformers==4.25.1
#   Downloading transformers-4.25.1-py3-none-any.whl.metadata (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (3.9.0)
# Collecting huggingface-hub<1.0,>=0.10.0 (from transformers==4.25.1)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (2022.3.15)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers==4.25.1) (4.66.4)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers==4.25.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers==4.25.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers==4.25.1) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers==4.25.1) (2024.6.2)
# Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 105.6 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 60.5 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 42.2 MB/s eta 0:00:00
# Installing collected packages: fsspec, huggingface-hub, transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.6.0
#     Uninstalling huggingface-hub-0.6.0:
#       Successfully uninstalled huggingface-hub-0.6.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.17.0
#     Uninstalling transformers-4.17.0:
#       Successfully uninstalled transformers-4.17.0
# Successfully installed fsspec-2024.6.1 huggingface-hub-0.23.4 transformers-4.25.1
# Collecting pytorch-lightning==1.6.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (1.23.5)
# Requirement already satisfied: torch>=1.8.* in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (2.0.1)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (6.0)
# Requirement already satisfied: fsspec!=2021.06.0,>=2021.05.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (2024.6.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (2.12.2)
# Requirement already satisfied: torchmetrics>=0.4.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (0.11.4)
# Collecting pyDeprecate>=0.3.1 (from pytorch-lightning==1.6.4)
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (23.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning==1.6.4) (4.4.0)
# Collecting protobuf<=3.20.1 (from pytorch-lightning==1.6.4)
#   Downloading protobuf-3.20.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (698 bytes)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (3.9.5)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.53.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (65.6.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.6.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.3.8)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.38.4)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (3.9.0)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (3.1.4)
# Requirement already satisfied: six in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (4.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from sympy->torch>=1.8.*->pytorch-lightning==1.6.4) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.2.2)
# Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 36.4 MB/s eta 0:00:00
# Downloading protobuf-3.20.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.4 MB/s eta 0:00:00
# Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pyDeprecate, protobuf, pytorch-lightning
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.0.1
#     Uninstalling pytorch-lightning-2.0.1:
#       Successfully uninstalled pytorch-lightning-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mysql-connector-python 8.1.0 requires protobuf<=4.21.12,>=4.21.1, but you have protobuf 3.20.1 which is incompatible.
# onnx 1.13.1 requires protobuf>=4.21, but you have protobuf 3.20.1 which is incompatible.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# watson-core 2.1.0 requires protobuf<5,>=4.21.6, but you have protobuf 3.20.1 which is incompatible.
# Successfully installed protobuf-3.20.1 pyDeprecate-0.3.2 pytorch-lightning-1.6.4
# Collecting timm==0.5.4
#   Downloading timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: torch>=1.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from timm==0.5.4) (2.0.1)
# Requirement already satisfied: torchvision in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from timm==0.5.4) (0.15.2)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.4->timm==0.5.4) (3.9.0)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.4->timm==0.5.4) (4.4.0)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.4->timm==0.5.4) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.4->timm==0.5.4) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.4->timm==0.5.4) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torchvision->timm==0.5.4) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torchvision->timm==0.5.4) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torchvision->timm==0.5.4) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->torchvision->timm==0.5.4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->torchvision->timm==0.5.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->torchvision->timm==0.5.4) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->torchvision->timm==0.5.4) (2024.6.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)
# Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 23.4 MB/s eta 0:00:00
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Collecting gradio
#   Downloading gradio-4.37.2-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting altair<6.0,>=4.2.0 (from gradio)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==1.0.2 (from gradio)
#   Downloading gradio_client-1.0.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (5.12.0)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (1.23.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (23.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (10.3.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 39.8 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (6.0)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.5.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio) (4.4.0)
# Collecting urllib3~=2.0 (from gradio)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from gradio-client==1.0.2->gradio) (2024.6.1)
# Collecting websockets<12.0,>=10.0 (from gradio-client==1.0.2->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Collecting anyio (from httpx>=0.24.1->gradio)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (3.7)
# Collecting sniffio (from httpx>=0.24.1->gradio)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting email_validator>=2.0.0 (from fastapi->gradio)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx>=0.24.1->gradio)
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-4.37.2-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 75.3 MB/s eta 0:00:00:00:0100:01
# Downloading gradio_client-1.0.2-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 31.8 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 67.6 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 24.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 25.5 MB/s eta 0:00:00
# Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 37.5 MB/s eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 39.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.0 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.5.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 130.2 MB/s eta 0:00:0000:010:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 12.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 28.3 MB/s eta 0:00:00
# Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 11.2 MB/s eta 0:00:00
# Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 17.1 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.5 MB/s eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 34.7 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 24.9 MB/s eta 0:00:00
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 26.0 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 21.1 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 21.5 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 33.6 MB/s eta 0:00:00
# Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 38.2 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 32.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 90.2 MB/s eta 0:00:00:00:01
# Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5583 sha256=c30f920eda0302bc94ed7352efeffe917921519046023b7f77cbdd7211f48ba1
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pydub, ffmpy, websockets, uvloop, urllib3, ujson, typing-extensions, tomlkit, sniffio, shellingham, semantic-version, ruff, python-multipart, python-dotenv, orjson, mdurl, httptools, h11, exceptiongroup, dnspython, annotated-types, aiofiles, uvicorn, pydantic-core, markdown-it-py, httpcore, email_validator, anyio, watchfiles, starlette, rich, pydantic, httpx, altair, typer, gradio-client, fastapi-cli, fastapi, gradio
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.19
#     Uninstalling urllib3-1.26.19:
#       Successfully uninstalled urllib3-1.26.19
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.27.59 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.2.2 which is incompatible.
# ibm-cloud-sdk-core 3.16.5 requires urllib3<2.0.0,>=1.26.0, but you have urllib3 2.2.2 which is incompatible.
# ibm-cos-sdk-core 2.12.0 requires urllib3<1.27,>=1.26.9, but you have urllib3 2.2.2 which is incompatible.
# onnx 1.13.1 requires protobuf>=4.21, but you have protobuf 3.20.1 which is incompatible.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# watson-core 2.1.0 requires protobuf<5,>=4.21.6, but you have protobuf 3.20.1 which is incompatible.
# watson-nlp 4.1.3 requires urllib3<1.27.0,>=1.26.18, but you have urllib3 2.2.2 which is incompatible.
# Successfully installed aiofiles-23.2.1 altair-5.3.0 annotated-types-0.7.0 anyio-4.4.0 dnspython-2.6.1 email_validator-2.2.0 exceptiongroup-1.2.1 fastapi-0.111.0 fastapi-cli-0.0.4 ffmpy-0.3.2 gradio-4.37.2 gradio-client-1.0.2 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.10.6 pydantic-2.8.2 pydantic-core-2.20.1 pydub-0.25.1 python-dotenv-1.0.1 python-multipart-0.0.9 rich-13.7.1 ruff-0.5.1 semantic-version-2.10.0 shellingham-1.5.4 sniffio-1.3.1 starlette-0.37.2 tomlkit-0.12.0 typer-0.12.3 typing-extensions-4.12.2 ujson-5.10.0 urllib3-2.2.2 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-11.0.3
# Collecting donut-python
#   Downloading donut_python-1.0.9-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers>=4.11.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from donut-python) (4.25.1)
# Requirement already satisfied: timm in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from donut-python) (0.5.4)
# Collecting datasets[vision] (from donut-python)
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from donut-python) (1.6.4)
# Collecting nltk (from donut-python)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from donut-python) (0.1.97)
# Collecting zss (from donut-python)
#   Downloading zss-1.2.0.tar.gz (9.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sconf>=0.2.3 (from donut-python)
#   Downloading sconf-0.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.23.5)
# Requirement already satisfied: torch>=1.8.* in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.0.1)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0)
# Requirement already satisfied: fsspec!=2021.06.0,>=2021.05.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.4->donut-python) (2024.6.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.12.2)
# Requirement already satisfied: torchmetrics>=0.4.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.11.4)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (23.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.12.2)
# Requirement already satisfied: protobuf<=3.20.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pytorch-lightning>=1.6.4->donut-python) (3.20.1)
# Requirement already satisfied: ruamel.yaml in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from sconf>=0.2.3->donut-python) (0.17.21)
# Requirement already satisfied: munch in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from sconf>=0.2.3->donut-python) (2.5.0)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers>=4.11.3->donut-python) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers>=4.11.3->donut-python) (0.23.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers>=4.11.3->donut-python) (2022.3.15)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers>=4.11.3->donut-python) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Collecting pyarrow>=15.0.0 (from datasets[vision]->donut-python)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets[vision]->donut-python)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from datasets[vision]->donut-python) (0.3.6)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from datasets[vision]->donut-python) (1.5.3)
# Collecting requests (from transformers>=4.11.3->donut-python)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xxhash (from datasets[vision]->donut-python)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets[vision]->donut-python)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec!=2021.06.0,>=2021.05.0 (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.4->donut-python)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from datasets[vision]->donut-python) (3.9.5)
# Requirement already satisfied: Pillow>=9.4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from datasets[vision]->donut-python) (10.3.0)
# Requirement already satisfied: click in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from nltk->donut-python) (8.0.4)
# Requirement already satisfied: joblib in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from nltk->donut-python) (1.1.1)
# Requirement already satisfied: torchvision in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from timm->donut-python) (0.15.2)
# Requirement already satisfied: six in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from aiohttp->datasets[vision]->donut-python) (4.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers>=4.11.3->donut-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers>=4.11.3->donut-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers>=4.11.3->donut-python) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests->transformers>=4.11.3->donut-python) (2024.6.2)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.53.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (65.6.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.6.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.3.8)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.38.4)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (3.1.4)
# Collecting dill<0.3.9,>=0.3.0 (from datasets[vision]->donut-python)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pandas->datasets[vision]->donut-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pandas->datasets[vision]->donut-python) (2022.7)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from sympy->torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.2.2)
# Downloading donut_python-1.0.9-py3-none-any.whl (21 kB)
# Downloading sconf-0.2.5-py3-none-any.whl (8.8 kB)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.3 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 61.5 MB/s eta 0:00:00
# Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 47.9 MB/s eta 0:00:0000:0100:01m
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 11.3 MB/s eta 0:00:00
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 69.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 36.0 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.9 MB/s eta 0:00:00
# Building wheels for collected packages: zss
#   Building wheel for zss (setup.py) ... done
#   Created wheel for zss: filename=zss-1.2.0-py3-none-any.whl size=6724 sha256=373f6acfad7b29526a95a63ca093484d3545e310f4e3fdf077df22cf48c138af
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/f6/61/2a/cf33ab7301cc318a13418d9a805c1832be561b46e7d9337625
# Successfully built zss
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: zss, xxhash, requests, pyarrow-hotfix, pyarrow, nltk, fsspec, dill, sconf, multiprocess, datasets, donut-python
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Uninstalling pyarrow-11.0.0:
#       Successfully uninstalled pyarrow-11.0.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibm-cloud-sdk-core 3.16.5 requires urllib3<2.0.0,>=1.26.0, but you have urllib3 2.2.2 which is incompatible.
# ibm-cos-sdk-core 2.12.0 requires urllib3<1.27,>=1.26.9, but you have urllib3 2.2.2 which is incompatible.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# watson-core 2.1.0 requires protobuf<5,>=4.21.6, but you have protobuf 3.20.1 which is incompatible.
# watson-nlp 4.1.3 requires pyarrow==11.0.0, but you have pyarrow 16.1.0 which is incompatible.
# watson-nlp 4.1.3 requires urllib3<1.27.0,>=1.26.18, but you have urllib3 2.2.2 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 donut-python-1.0.9 fsspec-2024.5.0 multiprocess-0.70.16 nltk-3.8.1 pyarrow-16.1.0 pyarrow-hotfix-0.6 requests-2.32.3 sconf-0.2.5 xxhash-3.4.1 zss-1.2.0

# %%
import argparse
import gradio as gr
import torch
from PIL import Image

from donut import DonutModel

# %%
def demo_process_vqa(input_img, question):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    user_prompt = task_prompt.replace("{user_input}", question)
    output = pretrained_model.inference(input_img, prompt=user_prompt)["predictions"][0]
    return output


def demo_process(input_img):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    output = pretrained_model.inference(image=input_img, prompt=task_prompt)["predictions"][0]
    return output

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--task", type=str, default="cord-v2")
parser.add_argument("--pretrained_path", type=str, default="naver-clova-ix/donut-base-finetuned-cord-v2")
args, left_argv = parser.parse_known_args()

task_name = args.task
if "docvqa" == task_name:
    task_prompt = "<s_docvqa><s_question>{user_input}</s_question><s_answer>"
else:  # rvlcdip, cord, ...
    task_prompt = f"<s_{task_name}>"

pretrained_model = DonutModel.from_pretrained(args.pretrained_path)

if torch.cuda.is_available():
    pretrained_model.half()
    device = torch.device("cuda")
    pretrained_model.to(device)
else:
    pretrained_model.encoder.to(torch.bfloat16)

pretrained_model.eval()

demo = gr.Interface(
    fn=demo_process_vqa if task_name == "docvqa" else demo_process,
    inputs=["image", "text"] if task_name == "docvqa" else "image",
    outputs="json",
    title=f"Donut 🍩 demonstration for `{task_name}` task",
)
demo.launch(debug=True, share=True)
# Out:
# /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/404 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/859M [00:00<?, ?B/s]
# /opt/conda/envs/Python-RT23.1-CUDA/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch-base_1708441372621/work/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# sentencepiece.bpe.model:   0%|          | 0.00/1.30M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://51d99158307028aea1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://51d99158307028aea1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
